# %%
from fim.data.datasets import HFDataset
from fim.data.dataloaders import FIMDataLoader

# %%
dataset = HFDataset("easytpp/volcano")
# Out:
# README.md:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# train.json:   0%|          | 0.00/264k [00:00<?, ?B/s]
# dev.json:   0%|          | 0.00/29.5k [00:00<?, ?B/s]
# test.json:   0%|          | 0.00/115k [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/181 [00:00<?, ? examples/s]

# %%
dataloaders = FIMDataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# {'dim_process': 1,
#  'seq_idx': 0,
#  'seq_len': 5,
#  'time_since_last_event': [0.0,
#   1.2096000000019551,
#   49.85280000000057,
#   20.822399999997288,
#   1439.7695999999996],
#  'time_since_start': [0.0,
#   1.2096000000019551,
#   51.062400000002526,
#   71.88479999999981,
#   1511.6543999999994],
#  'type_event': [0, 0, 0, 0, 0]}
