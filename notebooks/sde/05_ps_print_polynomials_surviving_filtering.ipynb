# %% [markdown]
# ## Use Polynomials.print_polynomial to print realizations of sampled polynomials

# %%
from fim.data_generation.sde.dynamical_systems import Polynomials
from fim.utils.plots.sde_data_exploration_plots import get_dynamical_system_data, show_paths_vector_fields_and_statistics

# %% [markdown]
# ### Global Options for all samples

# %%
global_state_dim = 2

global_num_realizations = 20
global_num_paths = 20
global_show_equation = True

global_bernoulli_survival_rate = 0.5

global_enforce_positivity = "abs"

global_sample_scale_per_dimension = True

integration_config = {
    "method": "EulerMaruyama",
    "time_step": 0.01,
    "steps_per_dt": 1,
    "num_steps": 1024,
    "num_paths": 20,
    "num_locations": 1024,
    "chunk_size": 2000,  # generate at one time so many realizations (to filter Nans)
    "reject_threshold": 100,
    "stochastic": True,
}

locations_params = {"type": "random_cube", "extension_perc": 0.0}

fig_config = {"dpi": 300, "figsize": 4}

paths_plt_config = {
    "linewidth": 0.5,
}

normal_initial_state = {
    "distribution": "normal",
    "mean": 0.0,
    "std_dev": 1.0,
    "activation": None,
}

uniform_initial_state = {
    "distribution": "uniform",
    "min": -10,
    "max": 10,
    "activation": None,
}

zero_dist = {"distribution": "fix", "fix_value": 0.0}
standard_normal_dist_with_bernoulli = {
    "distribution": "normal",
    "mean": 0.0,
    "std": 1.0,
    "bernoulli_survival_rate": global_bernoulli_survival_rate,
}
uniform_0_1_dist_with_bernoulli = {
    "distribution": "uniform",
    "min": 0.0,
    "max": 1.0,
    "bernoulli_survival_rate": global_bernoulli_survival_rate,
}
uniform_0_1_dist = {
    "distribution": "uniform",
    "min": 0.0,
    "max": 1.0,
    "bernoulli_survival_rate": 1.0,
}

scale_uniform = {
    "sample_per_dimension": global_sample_scale_per_dimension,
    "distribution": "uniform",
    "min": 0,
    "max": 1,
}
scale_fix = {"distribution": "fix", "fix_value": 1.0}


def show_general_plots(system):
    show_paths_vector_fields_and_statistics(system, integration_config, locations_params, fig_config, paths_plt_config, normalize=False)

# %% [markdown]
# ### Show degree 0.5, monomials sampled from 0.5 to 1

# %%
process_hyperparameters = {
    "name": "Polynomials",
    "data_bulk_name": "damped_linear_theory",
    "redo": True,
    "num_realizations": global_num_realizations,
    "state_dim": global_state_dim,
    "enforce_positivity": "clip",
    "show_equation": False,
    "observed_dimension": None,
    "max_degree_drift": 3,
    "max_degree_diffusion": 2,
    "drift_params": {
        "distribution": {"name": "normal", "std": 1},
        "degree_survival_rate": 0.5,
        "monomials_survival_distribution": {"name": "uniform", "min": 0.5, "max": 1},
        "scale": {"distribution": "fix", "fix_value": 1.0},
    },
    "diffusion_params": {
        "distribution": {"name": "normal", "std": 1},
        "degree_survival_rate": 0.5,
        "monomials_survival_distribution": {"name": "uniform", "min": 0.5, "max": 1},
        "scale": {"distribution": "fix", "fix_value": 1.0},
    },
    "initial_state": normal_initial_state,
}


data, drift_params, diffusion_params = get_dynamical_system_data(
    Polynomials(process_hyperparameters), integration_config, locations_params, normalize=True, return_params=True
)
# Out:
# Finite realizations generated:   0%|                                                                                                                      | 0/20 [00:00<?, ?it/s]
# Data sample step:   0%|                                                                                                                                 | 0/1024 [00:00<?, ?it/s]
# Data sample step:   1%|█▋                                                                                                                     | 14/1024 [00:00<00:07, 131.89it/s]
# Data sample step:   3%|███▎                                                                                                                   | 29/1024 [00:00<00:07, 140.08it/s]
# Data sample step:   4%|█████                                                                                                                  | 44/1024 [00:00<00:06, 143.23it/s]
# Data sample step:   6%|██████▊                                                                                                                | 59/1024 [00:00<00:06, 144.27it/s]
# Data sample step:   7%|████████▌                                                                                                              | 74/1024 [00:00<00:06, 145.40it/s]
# Data sample step:   9%|██████████▍                                                                                                            | 90/1024 [00:00<00:06, 148.28it/s]
# Data sample step:  10%|████████████▏                                                                                                         | 106/1024 [00:00<00:06, 150.18it/s]
# Data sample step:  12%|██████████████                                                                                                        | 122/1024 [00:00<00:05, 152.65it/s]
# Data sample step:  13%|███████████████▉                                                                                                      | 138/1024 [00:00<00:05, 154.10it/s]
# Data sample step:  15%|█████████████████▋                                                                                                    | 154/1024 [00:01<00:05, 153.59it/s]
# Data sample step:  17%|███████████████████▌                                                                                                  | 170/1024 [00:01<00:05, 151.82it/s]
# Data sample step:  18%|█████████████████████▍                                                                                                | 186/1024 [00:01<00:05, 152.73it/s]
# Data sample step:  20%|███████████████████████▎                                                                                              | 202/1024 [00:01<00:05, 153.89it/s]
# Data sample step:  21%|█████████████████████████                                                                                             | 218/1024 [00:01<00:05, 155.20it/s]
# Data sample step:  23%|██████████████████████████▉                                                                                           | 234/1024 [00:01<00:05, 155.01it/s]
# Data sample step:  24%|████████████████████████████▊                                                                                         | 250/1024 [00:01<00:05, 153.04it/s]
# Data sample step:  26%|██████████████████████████████▋                                                                                       | 266/1024 [00:01<00:04, 152.16it/s]
# Data sample step:  28%|████████████████████████████████▍                                                                                     | 282/1024 [00:01<00:04, 152.06it/s]
# Data sample step:  29%|██████████████████████████████████▎                                                                                   | 298/1024 [00:01<00:04, 149.76it/s]
# Data sample step:  31%|████████████████████████████████████                                                                                  | 313/1024 [00:02<00:04, 148.34it/s]
# Data sample step:  32%|█████████████████████████████████████▉                                                                                | 329/1024 [00:02<00:04, 150.26it/s]
# Data sample step:  34%|███████████████████████████████████████▊                                                                              | 345/1024 [00:02<00:04, 150.72it/s]
# Data sample step:  35%|█████████████████████████████████████████▌                                                                            | 361/1024 [00:02<00:04, 147.67it/s]
# Data sample step:  37%|███████████████████████████████████████████▎                                                                          | 376/1024 [00:02<00:04, 147.77it/s]
# Data sample step:  38%|█████████████████████████████████████████████                                                                         | 391/1024 [00:02<00:04, 145.42it/s]
# Data sample step:  40%|██████████████████████████████████████████████▊                                                                       | 406/1024 [00:02<00:04, 145.75it/s]
# Data sample step:  41%|████████████████████████████████████████████████▌                                                                     | 421/1024 [00:02<00:04, 144.34it/s]
# Data sample step:  43%|██████████████████████████████████████████████████▎                                                                   | 437/1024 [00:02<00:03, 147.68it/s]
# Data sample step:  44%|████████████████████████████████████████████████████▏                                                                 | 453/1024 [00:03<00:03, 150.21it/s]
# Data sample step:  46%|██████████████████████████████████████████████████████                                                                | 469/1024 [00:03<00:03, 150.41it/s]
# Data sample step:  47%|███████████████████████████████████████████████████████▉                                                              | 485/1024 [00:03<00:03, 151.09it/s]
# Data sample step:  49%|█████████████████████████████████████████████████████████▋                                                            | 501/1024 [00:03<00:03, 149.45it/s]
89%|█████████████████████████████████████████████████████████████████████████████████████████████████████████             | 912/1024 [00:06<00:00, 153.27it/s]
# Data sample step:  91%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▉           | 928/1024 [00:06<00:00, 152.71it/s]
# Data sample step:  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▊         | 944/1024 [00:06<00:00, 153.00it/s]
# Data sample step:  94%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▋       | 960/1024 [00:06<00:00, 152.46it/s]
# Data sample step:  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍     | 976/1024 [00:06<00:00, 152.96it/s]
# Data sample step:  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎   | 992/1024 [00:06<00:00, 150.46it/s]
# Data sample step:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 1008/1024 [00:06<00:00, 150.08it/s]
# Data sample step: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1024/1024 [00:06<00:00, 151.24it/s]

# %%
Polynomials.print_polynomials(drift_params, max_degree=3, precision=2)
# Out:
# Realization:  0
# -0.83x_1 -0.11x_2
# -0.23 -0.77x_1 -0.42x_2 -1.98x_1^2 -0.51x_1x_2 -0.78x_1^3 +1.04x_1x_2^2 -1.6x_2^3
#
#
# Realization:  1
# -0.24x_1 +2.02x_2
# +0.08 -2.0x_1 +0.19x_1^2 -0.89x_1x_2 -0.6x_2^2 +0.07x_1^3 -2.13x_1^2x_2 +0.61x_1x_2^2
#
#
# Realization:  2
# +0.68
# +0.26x_2
#
#
# Realization:  3
# -0.49 +0.12x_2 +0.69x_1^2 -0.95x_1x_2 -1.0x_1^3 +0.52x_1^2x_2 +1.15x_1x_2^2 -1.17x_2^3
# -0.64x_1^2x_2
#
#
# Realization:  4
# -2.05x_1 +1.2x_1^2 +0.15x_2^2 -0.75x_1^3 -0.37x_1^2x_2 -0.36x_1x_2^2 -0.58x_2^3
# +0.42x_1^3
#
#
# Realization:  5
# -0.44x_1^2x_2
# -0.74x_2 -1.01x_1^2 +1.78x_1x_2 +0.4x_2^2 +0.97x_1^3 +1.28x_1^2x_2 +0.6x_1x_2^2 -0.64x_2^3
#
#
# Realization:  6
# -0.79x_1
# -0.61x_1 +0.07x_2
#
#
# Realization:  7
# -0.28x_1 -1.02x_2 -2.42x_1^3 -0.44x_1^2x_2 -1.23x_2^3
# -0.24x_1^2 -0.27x_1x_2 -0.21x_2^2 +1.87x_1^3 -0.56x_1^2x_2 +0.3x_2^3
#
#
# Realization:  8
# -0.12 -1.03x_1 +0.09x_2 -1.74x_1^3 +0.35x_1^2x_2 +0.68x_1x_2^2 -0.71x_2^3
# -2.29x_1 -2.45x_2 +0.76x_1^2 +1.41x_2^2 -1.3x_1^3 -0.7x_1^2x_2 +0.41x_1x_2^2 -0.27x_2^3
#
#
# Realization:  9
# -0.91x_1
# +0.5 +0.03x_1^3 +0.13x_1^2x_2
#
#
# Realization:  10
# -0.29x_2
# -1.04x_1^2 +0.14x_1x_2 -0.95x_2^2 +0.26x_1^3 +0.36x_1^2x_2 -0.49x_1x_2^2 -1.49x_2^3
#
#
# Realization:  11
# -1.31x_1 +1.69x_2 +0.04x_1^2 -1.04x_1x_2 -1.55x_2^2 -0.01x_1^2x_2
# -1.79x_1^2x_2
#
#
# Realization:  12
# +0.16x_1 +1.06x_2 -1.19x_1^3 +0.83x_1^2x_2 +0.42x_1x_2^2 -0.44x_2^3
# -0.28x_1 +0.57x_2 -0.6x_1^2 +1.03x_1x_2 +0.04x_2^2 +0.23x_1^3 +0.74x_1^2x_2 -0.88x_2^3
#
#
# Realization:  13
# -0.68x_1 -0.46x_2 -0.22x_1^2 -1.03x_1x_2^2
# -0.37x_1 -1.01x_1^3 +0.08x_1^2x_2 -0.53x_1x_2^2 -0.03x_2^3
#
#
# Realization:  14
# -0.6
# -0.23x_1^2x_2 +0.16x_1x_2^2 -0.19x_2^3
#
#
# Realization:  15
# -0.39x_1^3 +0.12x_1^2x_2 -0.7x_1x_2^2 -0.49x_2^3
# -0.79x_1 -1.0x_2 -0.77x_1^3 -0.0x_1^2x_2 +0.12x_1x_2^2 -0.9x_2^3
#
#
# Realization:  16
# -0.43 -0.87x_1 +0.85x_2 -1.7x_1^3 -0.36x_1^2x_2 -0.7x_1x_2^2 +0.97x_2^3
# +0.36x_1^3 -0.68x_1^2x_2 -1.12x_2^3
#
#
# Realization:  17
# +0.24x_1 -0.61x_2 -1.6x_1^3 +1.59x_1x_2^2 -0.34x_2^3
# +0.45
#
#
# Realization:  18
# +0.6x_1x_2
# -0.34 +0.5x_2 +0.05x_1^3 +0.03x_1^2x_2 -0.67x_2^3
#
#
# Realization:  19
# -0.39x_2
# -0.06 +1.7x_2^2 +1.35x_1^3 -1.92x_2^3

# %% [markdown]
# ### Show degree 0.75, monomials 0.5

# %%
process_hyperparameters = {
    "name": "Polynomials",
    "data_bulk_name": "damped_linear_theory",
    "redo": True,
    "num_realizations": global_num_realizations,
    "state_dim": global_state_dim,
    "enforce_positivity": "clip",
    "show_equation": False,
    "observed_dimension": None,
    "max_degree_drift": 3,
    "max_degree_diffusion": 2,
    "drift_params": {
        "distribution": {"name": "normal", "std": 1},
        "degree_survival_rate": 0.75,
        "monomials_survival_distribution": {"name": "fix", "fix_value": 0.5},
        "scale": {"distribution": "fix", "fix_value": 1.0},
    },
    "diffusion_params": {
        "distribution": {"name": "normal", "std": 1},
        "degree_survival_rate": 0.75,
        "monomials_survival_distribution": {"name": "fix", "fix_value": 0.5},
        "scale": {"distribution": "fix", "fix_value": 1.0},
    },
    "initial_state": normal_initial_state,
}


data, drift_params, diffusion_params = get_dynamical_system_data(
    Polynomials(process_hyperparameters), integration_config, locations_params, normalize=True, return_params=True
)
# Out:
# Finite realizations generated:   0%|                                                                                                                      | 0/20 [00:00<?, ?it/s]
# Data sample step:   0%|                                                                                                                                 | 0/1024 [00:00<?, ?it/s]
# Data sample step:   1%|█▋                                                                                                                     | 15/1024 [00:00<00:06, 148.64it/s]
# Data sample step:   3%|███▌                                                                                                                   | 31/1024 [00:00<00:06, 151.03it/s]
# Data sample step:   5%|█████▍                                                                                                                 | 47/1024 [00:00<00:06, 154.28it/s]
# Data sample step:   6%|███████▎                                                                                                               | 63/1024 [00:00<00:06, 153.32it/s]
# Data sample step:   8%|█████████▏                                                                                                             | 79/1024 [00:00<00:06, 145.98it/s]
# Data sample step:   9%|██████████▉                                                                                                            | 94/1024 [00:00<00:06, 145.32it/s]
# Data sample step:  11%|████████████▋                                                                                                         | 110/1024 [00:00<00:06, 149.23it/s]
# Data sample step:  12%|██████████████▌                                                                                                       | 126/1024 [00:00<00:05, 151.43it/s]
# Data sample step:  14%|████████████████▍                                                                                                     | 143/1024 [00:00<00:05, 154.93it/s]
# Data sample step:  16%|██████████████████▎                                                                                                   | 159/1024 [00:01<00:05, 155.70it/s]
# Data sample step:  61%|███████████████████████████████████████████████████████████████████████▋                                              | 622/1024 [00:03<00:02, 160.15it/s]
# Data sample step:  62%|█████████████████████████████████████████████████████████████████████████▋                                            | 639/1024 [00:04<00:02, 160.46it/s]
# Data sample step:  64%|███████████████████████████████████████████████████████████████████████████▌                                          | 656/1024 [00:04<00:02, 160.82it/s]
# Data sample step:  66%|█████████████████████████████████████████████████████████████████████████████▌                                        | 673/1024 [00:04<00:02, 160.53it/s]
# Data sample step:  67%|███████████████████████████████████████████████████████████████████████████████▌                                      | 690/1024 [00:04<00:02, 158.47it/s]
# Data sample step:  69%|█████████████████████████████████████████████████████████████████████████████████▎                                    | 706/1024 [00:04<00:02, 156.74it/s]
# Data sample step:  71%|███████████████████████████████████████████████████████████████████████████████████▏                                  | 722/1024 [00:04<00:01, 156.71it/s]
# Data sample step:  72%|█████████████████████████████████████████████████████████████████████████████████████                                 | 738/1024 [00:04<00:01, 148.19it/s]
# Data sample step:  74%|██████████████████████████████████████████████████████████████████████████████████████▊                               | 753/1024 [00:04<00:01, 146.15it/s]
# Data sample step:  75%|████████████████████████████████████████████████████████████████████████████████████████▌                             | 769/1024 [00:04<00:01, 149.41it/s]
# Data sample step:  77%|██████████████████████████████████████████████████████████████████████████████████████████▍                           | 785/1024 [00:05<00:01, 150.50it/s]
# Data sample step:  78%|████████████████████████████████████████████████████████████████████████████████████████████▎                         | 801/1024 [00:05<00:01, 153.13it/s]
# Data sample step:  80%|██████████████████████████████████████████████████████████████████████████████████████████████▏                       | 817/1024 [00:05<00:01, 154.74it/s]
# Data sample step:  81%|███████████████████████████████████████████████████████████████████████████████████████████████▉                      | 833/1024 [00:05<00:01, 156.26it/s]
# Data sample step:  83%|█████████████████████████████████████████████████████████████████████████████████████████████████▊                    | 849/1024 [00:05<00:01, 143.04it/s]
# Data sample step:  84%|███████████████████████████████████████████████████████████████████████████████████████████████████▌                  | 864/1024 [00:05<00:01, 143.45it/s]
# Data sample step:  86%|█████████████████████████████████████████████████████████████████████████████████████████████████████▎                | 879/1024 [00:05<00:01, 144.76it/s]
# Data sample step:  87%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏              | 895/1024 [00:05<00:00, 147.93it/s]
# Data sample step:  89%|████████████████████████████████████████████████████████████████████████████████████████████████████████▉             | 911/1024 [00:05<00:00, 150.91it/s]
# Data sample step:  91%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▊           | 927/1024 [00:05<00:00, 153.27it/s]
# Data sample step:  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▋         | 943/1024 [00:06<00:00, 154.41it/s]
# Data sample step:  94%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▌       | 959/1024 [00:06<00:00, 153.36it/s]
# Data sample step:  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 975/1024 [00:06<00:00, 151.74it/s]
# Data sample step:  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 991/1024 [00:06<00:00, 152.95it/s]
# Data sample step:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████  | 1007/1024 [00:06<00:00, 154.29it/s]
# Data sample step: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1024/1024 [00:06<00:00, 156.41it/s]

# %%
Polynomials.print_polynomials(drift_params, max_degree=3, precision=2)
# Out:
# Realization:  0
# -0.2x_2^3
# -0.45 +0.49x_1^2 +0.68x_1x_2 +0.71x_2^2 +1.14x_1^3 -0.5x_1^2x_2 -0.83x_2^3
#
#
# Realization:  1
# -0.73x_1 -0.09x_1^2 +2.13x_2^3
# +0.9 -0.58x_1 -1.52x_2 -1.46x_1^2 -0.86x_1^2x_2 -0.35x_2^3
#
#
# Realization:  2
# -0.11x_2^2
# +1.44 -0.11x_2 -0.4x_2^3
#
#
# Realization:  3
# -0.21x_1
# -1.14 -0.15x_1x_2 +1.37x_1^3 +0.21x_1^2x_2 -0.71x_2^3
#
#
# Realization:  4
# +1.67 -0.06x_1^2x_2 -0.36x_1x_2^2
# +0.84x_1^2 -0.72x_1x_2 +0.31x_2^2 +0.77x_1^3 -0.39x_1^2x_2 +0.06x_1x_2^2 -0.74x_2^3
#
#
# Realization:  5
# +0.14x_2^3
# +1.32x_1 +0.46x_2 -0.81x_1^2 +1.11x_1x_2 +1.71x_2^2 -0.68x_1^2x_2 +0.57x_1x_2^2 -0.4x_2^3
#
#
# Realization:  6
# +0.42 -0.05x_1 +0.15x_1^2 +0.47x_1x_2
# -1.35 -0.53x_1^2 +0.4x_1x_2 -1.92x_1^3 -0.37x_1^2x_2
#
#
# Realization:  7
# -0.37 -0.4x_2^2 -1.13x_1^3 +0.39x_1^2x_2 +0.89x_2^3
# +0.81x_1x_2 +1.13x_2^2 -0.59x_1^2x_2 -2.16x_1x_2^2 -2.24x_2^3
#
#
# Realization:  8
# -0.62x_1^3 +0.22x_2^3
# +0.85 -2.33x_1x_2^2 -0.12x_2^3
#
#
# Realization:  9
# -0.84x_1 -0.54x_2 +0.71x_1^2x_2 +0.22x_1x_2^2
# -0.29x_1^2 -0.53x_1x_2 -0.11x_2^2 -1.01x_1^2x_2 -0.98x_2^3
#
#
# Realization:  10
# -0.37 +2.77x_1^2 +0.21x_1x_2 -0.22x_2^2 -0.59x_1^3 +0.0x_1^2x_2
# -0.03x_2 +0.2x_1^2
#
#
# Realization:  11
# -2.03 -0.25x_1 +0.88x_1^2 -0.46x_1x_2
# +0.26 +0.99x_1 -0.77x_2 -0.29x_2^2 -0.51x_2^3
#
#
# Realization:  12
# -1.0 -1.88x_1x_2 +0.4x_1^3 -1.34x_1^2x_2 +0.87x_2^3
# -0.45 +0.49x_1^3 +0.19x_1^2x_2 -1.0x_1x_2^2
#
#
# Realization:  13
# -1.99 -0.1x_1^2 -0.17x_1x_2
# -0.49 +0.97x_1 -1.18x_1^3 -0.99x_1^2x_2 -0.7x_2^3
#
#
# Realization:  14
# +1.37x_1 -0.68x_1^3 -1.05x_1^2x_2 -0.75x_2^3
# -0.72x_1^2x_2 +0.29x_2^3
#
#
# Realization:  15
# -1.75x_1 +0.87x_2 -0.35x_1^3 +0.63x_1^2x_2 +0.03x_1x_2^2 +0.3x_2^3
# -0.68x_2^3
#
#
# Realization:  16
# -1.84x_1 +0.61x_2
# +1.08 -0.69x_1 +0.08x_2 -0.52x_1^3 +1.01x_1^2x_2 -0.87x_2^3
#
#
# Realization:  17
# +0.98 -0.52x_2 +0.19x_1x_2^2 -2.16x_2^3
# +1.82x_1 -0.69x_1x_2 -1.19x_2^2
#
#
# Realization:  18
# -0.62x_1 -0.35x_1x_2 +1.89x_1^2x_2 -0.68x_1x_2^2
# -0.47x_1^2 +1.05x_1x_2 -0.0x_2^2 -0.46x_1^3
#
#
# Realization:  19
# +0.23x_1 +0.26x_2 +0.64x_1^2 +0.72x_1x_2 -0.92x_2^2 -0.93x_1^3 +0.82x_1^2x_2 -0.23x_1x_2^2 +0.79x_2^3
# +1.25x_1 -1.92x_2

# %% [markdown]
# ### Show degree 0.5, monomials 0.25

# %%
process_hyperparameters = {
    "name": "Polynomials",
    "data_bulk_name": "damped_linear_theory",
    "redo": True,
    "num_realizations": global_num_realizations,
    "state_dim": global_state_dim,
    "enforce_positivity": "clip",
    "show_equation": False,
    "observed_dimension": None,
    "max_degree_drift": 3,
    "max_degree_diffusion": 2,
    "drift_params": {
        "distribution": {"name": "normal", "std": 1},
        "degree_survival_rate": 0.5,
        "monomials_survival_distribution": {"name": "fix", "fix_value": 0.25},
        "scale": {"distribution": "fix", "fix_value": 1.0},
    },
    "diffusion_params": {
        "distribution": {"name": "normal", "std": 1},
        "degree_survival_rate": 0.5,
        "monomials_survival_distribution": {"name": "fix", "fix_value": 0.25},
        "scale": {"distribution": "fix", "fix_value": 1.0},
    },
    "initial_state": normal_initial_state,
}


data, drift_params, diffusion_params = get_dynamical_system_data(
    Polynomials(process_hyperparameters), integration_config, locations_params, normalize=True, return_params=True
)
# Out:
# Finite realizations generated:   0%|                                                                                                                      | 0/20 [00:00<?, ?it/s]
# Data sample step:   0%|                                                                                                                                 | 0/1024 [00:00<?, ?it/s]
# Data sample step:   2%|█▊                                                                                                                     | 16/1024 [00:00<00:06, 153.62it/s]
# Data sample step:   3%|███▋                                                                                                                   | 32/1024 [00:00<00:06, 149.90it/s]
# Data sample step:   5%|█████▍                                                                                                                 | 47/1024 [00:00<00:06, 147.06it/s]
# Data sample step:   6%|███████▏                                                                                                               | 62/1024 [00:00<00:06, 142.45it/s]
# Data sample step:   8%|█████████                                                                                                              | 78/1024 [00:00<00:06, 145.28it/s]
# Data sample step:   9%|██████████▊                                                                                                            | 93/1024 [00:00<00:06, 144.41it/s]
# Data sample step:  11%|████████████▍                                                                                                         | 108/1024 [00:00<00:06, 144.78it/s]
# Data sample step:  12%|██████████████▏                                                                                                       | 123/1024 [00:00<00:06, 142.39it/s]
# Data sample step:  13%|███████████████▉                                                                                                      | 138/1024 [00:00<00:06, 142.69it/s]
# Data sample step:  15%|█████████████████▋                                                                                                    | 153/1024 [00:01<00:06, 141.74it/s]
# Data sample step:  17%|███████████████████▍                                                                                                  | 169/1024 [00:01<00:05, 145.48it/s]
# Data sample step:  18%|█████████████████████▎                                                                                                | 185/1024 [00:01<00:05, 148.42it/s]
# Data sample step:  20%|███████████████████████▏                                                                                              | 201/1024 [00:01<00:05, 151.16it/s]
# Data sample step:  21%|█████████████████████████                                                                                             | 217/1024 [00:01<00:05, 153.31it/s]
# Data sample step:  23%|██████████████████████████▊                                                                                           | 233/1024 [00:01<00:05, 154.97it/s]
# Data sample step:  24%|████████████████████████████▋                                                                                         | 249/1024 [00:01<00:04, 155.78it/s]
# Data sample step:  26%|██████████████████████████████▌                                                                                       | 265/1024 [00:01<00:04, 156.74it/s]
# Data sample step:  27%|████████████████████████████████▍                                                                                     | 281/1024 [00:01<00:04, 154.44it/s]
# Data sample step:  29%|██████████████████████████████████▏                                                                                   | 297/1024 [00:01<00:04, 155.02it/s]
# Data sample step:  31%|████████████████████████████████████                                                                                  | 313/1024 [00:02<00:04, 155.15it/s]
# Data sample step:  32%|█████████████████████████████████████▉                                                                                | 329/1024 [00:02<00:04, 155.83it/s]
# Data sample step:  74%|███████████████████████████████████████████████████████████████████████████████████████▋                              | 761/1024 [00:04<00:01, 157.20it/s]
# Data sample step:  76%|█████████████████████████████████████████████████████████████████████████████████████████▌                            | 777/1024 [00:05<00:01, 157.50it/s]
# Data sample step:  77%|███████████████████████████████████████████████████████████████████████████████████████████▍                          | 793/1024 [00:05<00:01, 157.96it/s]
# Data sample step:  79%|█████████████████████████████████████████████████████████████████████████████████████████████▏                        | 809/1024 [00:05<00:01, 157.74it/s]
# Data sample step:  81%|███████████████████████████████████████████████████████████████████████████████████████████████                       | 825/1024 [00:05<00:01, 158.14it/s]
# Data sample step:  82%|████████████████████████████████████████████████████████████████████████████████████████████████▉                     | 841/1024 [00:05<00:01, 158.25it/s]
# Data sample step:  84%|██████████████████████████████████████████████████████████████████████████████████████████████████▊                   | 857/1024 [00:05<00:01, 158.43it/s]
# Data sample step:  85%|████████████████████████████████████████████████████████████████████████████████████████████████████▌                 | 873/1024 [00:05<00:00, 158.15it/s]
# Data sample step:  87%|██████████████████████████████████████████████████████████████████████████████████████████████████████▍               | 889/1024 [00:05<00:00, 158.30it/s]
# Data sample step:  88%|████████████████████████████████████████████████████████████████████████████████████████████████████████▎             | 905/1024 [00:05<00:00, 158.74it/s]
# Data sample step:  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▏           | 921/1024 [00:05<00:00, 159.03it/s]
# Data sample step:  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▉          | 937/1024 [00:06<00:00, 158.45it/s]
# Data sample step:  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▊        | 953/1024 [00:06<00:00, 158.87it/s]
# Data sample step:  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▋      | 969/1024 [00:06<00:00, 158.79it/s]
# Data sample step:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌    | 985/1024 [00:06<00:00, 158.33it/s]
# Data sample step:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎  | 1001/1024 [00:06<00:00, 158.36it/s]
# Data sample step:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏| 1017/1024 [00:06<00:00, 158.77it/s]

# %%
Polynomials.print_polynomials(drift_params, max_degree=3, precision=2)
# Out:
# Realization:  0
# -1.08x_1^3
# +0.01x_2
#
#
# Realization:  1
# +1.73x_2^3
# -0.54x_1x_2^2 -1.59x_2^3
#
#
# Realization:  2
# -1.03x_2
# -0.67x_1^2x_2
#
#
# Realization:  3
# -0.33x_2^3
# -0.0x_2
#
#
# Realization:  4
# -2.1x_1^3
# -0.37x_1^2 +0.68x_1^2x_2 -1.45x_1x_2^2
#
#
# Realization:  5
# +0.32
# +0.53
#
#
# Realization:  6
# +0.22x_1^2x_2
# -1.02x_2 -0.02x_1^2
#
#
# Realization:  7
# +0.05x_2 -0.2x_2^2 -1.63x_1^3
# +0.61
#
#
# Realization:  8
# -0.23x_1x_2^2
# +0.84 +0.77x_1^2
#
#
# Realization:  9
# +0.16
# -0.03x_2^2
#
#
# Realization:  10
# +0.91x_2^2
# -0.24x_2^3
#
#
# Realization:  11
# -0.8x_1^3
# +0.71x_1^3 -1.78x_2^3
#
#
# Realization:  12
# -0.14x_2 +0.47x_1^2 +1.08x_1^2x_2
# -0.55x_1^3 -0.07x_2^3
#
#
# Realization:  13
# +0.67 +0.15x_2^2
# -0.97
#
#
# Realization:  14
# +0.73x_2 -0.97x_2^3
# +1.12x_1 -0.94x_2 -0.78x_1x_2^2
#
#
# Realization:  15
# +0.87x_2^2
# -0.35x_1^2x_2
#
#
# Realization:  16
# -0.59x_2^2
# -0.53x_1^2x_2
#
#
# Realization:  17
# +0.92 +0.7x_2^2
# +1.25x_2 -1.31x_1x_2 +0.08x_1x_2^2
#
#
# Realization:  18
# -0.3x_2^2
# +0.73 +0.46x_1x_2^2
#
#
# Realization:  19
# -2.08x_1x_2^2
# +1.46x_1x_2 +0.13x_1^2x_2 -0.17x_2^3

# %% [markdown]
# ### Show Uniform Degree

# %%
process_hyperparameters = {
    "name": "Polynomials",
    "data_bulk_name": "damped_linear_theory",
    "redo": True,
    "num_realizations": global_num_realizations,
    "state_dim": global_state_dim,
    "enforce_positivity": "clip",
    "show_equation": False,
    "observed_dimension": None,
    "max_degree_drift": 3,
    "max_degree_diffusion": 2,
    "drift_params": {
        "distribution": {"name": "normal", "std": 1},
        "uniform_degree": True,
        "degree_survival_rate": 0.5,
        "monomials_survival_distribution": {"name": "fix", "fix_value": 0.25},
        "scale": {"distribution": "fix", "fix_value": 1.0},
    },
    "diffusion_params": {
        "distribution": {"name": "normal", "std": 1},
        "uniform_degree": True,
        "degree_survival_rate": 0.5,
        "monomials_survival_distribution": {"name": "fix", "fix_value": 0.25},
        "scale": {"distribution": "fix", "fix_value": 1.0},
    },
    "initial_state": normal_initial_state,
}


data, drift_params, diffusion_params = get_dynamical_system_data(
    Polynomials(process_hyperparameters), integration_config, locations_params, normalize=True, return_params=True
)
# Out:
# Finite realizations generated:   0%|                                                                                                                      | 0/20 [00:00<?, ?it/s]
# Data sample step:   0%|                                                                                                                                 | 0/1024 [00:00<?, ?it/s]
# Data sample step:   2%|█▊                                                                                                                     | 16/1024 [00:00<00:06, 153.26it/s]
# Data sample step:   3%|███▋                                                                                                                   | 32/1024 [00:00<00:06, 156.31it/s]
# Data sample step:   5%|█████▌                                                                                                                 | 48/1024 [00:00<00:06, 157.06it/s]
# Data sample step:   6%|███████▌                                                                                                               | 65/1024 [00:00<00:06, 158.33it/s]
# Data sample step:   8%|█████████▍                                                                                                             | 81/1024 [00:00<00:05, 158.67it/s]
# Data sample step:   9%|███████████▎                                                                                                           | 97/1024 [00:00<00:05, 158.80it/s]
# Data sample step:  11%|█████████████                                                                                                         | 113/1024 [00:00<00:05, 158.86it/s]
# Data sample step:  13%|██████████████▊                                                                                                       | 129/1024 [00:00<00:05, 154.92it/s]
# Data sample step:  14%|████████████████▋                                                                                                     | 145/1024 [00:00<00:05, 155.40it/s]
# Data sample step:  16%|██████████████████▌                                                                                                   | 161/1024 [00:01<00:05, 152.44it/s]
# Data sample step:  17%|████████████████████▍                                                                                                 | 177/1024 [00:01<00:05, 149.57it/s]
# Data sample step:  19%|██████████████████████▏                                                                                               | 192/1024 [00:01<00:05, 148.29it/s]
# Data sample step:  20%|███████████████████████▉                                                                                              | 208/1024 [00:01<00:05, 150.17it/s]
# Data sample step:  22%|█████████████████████████▊                                                                                            | 224/1024 [00:01<00:05, 148.94it/s]
# Data sample step:  23%|███████████████████████████▌                                                                                          | 239/1024 [00:01<00:05, 148.12it/s]
# Data sample step:  25%|█████████████████████████████▎                                                                                        | 254/1024 [00:01<00:05, 145.32it/s]
# Data sample step:  26%|██████████████████████████████▉                                                                                       | 269/1024 [00:01<00:05, 140.86it/s]
# Data sample step:  28%|████████████████████████████████▋                                                                                     | 284/1024 [00:01<00:05, 141.15it/s]
# Data sample step:  71%|███████████████████████████████████████████████████████████████████████████████████▌                                  | 725/1024 [00:04<00:02, 149.24it/s]
# Data sample step:  72%|█████████████████████████████████████████████████████████████████████████████████████▎                                | 740/1024 [00:04<00:01, 147.68it/s]
# Data sample step:  74%|███████████████████████████████████████████████████████████████████████████████████████                               | 755/1024 [00:05<00:01, 146.68it/s]
# Data sample step:  75%|████████████████████████████████████████████████████████████████████████████████████████▊                             | 771/1024 [00:05<00:01, 148.41it/s]
# Data sample step:  77%|██████████████████████████████████████████████████████████████████████████████████████████▋                           | 787/1024 [00:05<00:01, 149.01it/s]
# Data sample step:  78%|████████████████████████████████████████████████████████████████████████████████████████████▌                         | 803/1024 [00:05<00:01, 150.41it/s]
# Data sample step:  80%|██████████████████████████████████████████████████████████████████████████████████████████████▍                       | 819/1024 [00:05<00:01, 152.85it/s]
# Data sample step:  82%|████████████████████████████████████████████████████████████████████████████████████████████████▏                     | 835/1024 [00:05<00:01, 154.08it/s]
# Data sample step:  83%|██████████████████████████████████████████████████████████████████████████████████████████████████                    | 851/1024 [00:05<00:01, 148.16it/s]
# Data sample step:  85%|███████████████████████████████████████████████████████████████████████████████████████████████████▊                  | 866/1024 [00:05<00:01, 141.59it/s]
# Data sample step:  86%|█████████████████████████████████████████████████████████████████████████████████████████████████████▌                | 881/1024 [00:05<00:01, 130.25it/s]
# Data sample step:  87%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏              | 895/1024 [00:06<00:01, 128.54it/s]
# Data sample step:  89%|████████████████████████████████████████████████████████████████████████████████████████████████████████▉             | 911/1024 [00:06<00:00, 135.91it/s]
# Data sample step:  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▌           | 925/1024 [00:06<00:00, 130.29it/s]
# Data sample step:  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▏         | 939/1024 [00:06<00:00, 117.03it/s]
# Data sample step:  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▉        | 954/1024 [00:06<00:00, 124.77it/s]
# Data sample step:  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▊      | 970/1024 [00:06<00:00, 133.17it/s]
# Data sample step:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌    | 986/1024 [00:06<00:00, 138.06it/s]
# Data sample step:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎  | 1001/1024 [00:06<00:00, 135.19it/s]
# Data sample step:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████ | 1016/1024 [00:06<00:00, 137.71it/s]

# %%
Polynomials.print_polynomials(drift_params, max_degree=4, precision=2)
# Out:
# Realization:  0
# +0.05x_2^3
# -1.69x_2^3
#
#
# Realization:  1
# +1.0x_2^3
# -0.51x_2
#
#
# Realization:  2
# +0.66 +0.19x_1x_2^2 +0.23x_2^3
# -0.52x_1^2x_2
#
#
# Realization:  3
# -0.07
# +0.52x_1 -2.13x_2 +0.28x_2^2
#
#
# Realization:  4
# -1.01x_1^3
# -0.24x_1^3
#
#
# Realization:  5
# +0.52x_1x_2
# -0.96x_2^3
#
#
# Realization:  6
# -0.26x_2 +1.57x_1^2x_2 +0.62x_1x_2^2
# -0.69x_1^3 -1.77x_2^3
#
#
# Realization:  7
# +0.2x_2
# +2.19
#
#
# Realization:  8
# +1.12x_1 -0.08x_1x_2^2
# +0.23x_1^2
#
#
# Realization:  9
# -0.11x_1^3 +0.85x_1^2x_2
# -0.6x_1^3 -1.85x_2^3
#
#
# Realization:  10
# +0.26x_1x_2 +0.47x_2^3
# -1.23x_1^2x_2
#
#
# Realization:  11
# -0.3x_1
# +0.56 -1.86x_2 -0.1x_1^3
#
#
# Realization:  12
# -0.72x_2 +0.21x_1x_2
# -0.81x_2^3
#
#
# Realization:  13
# -0.24x_1x_2^2 +0.29x_2^3
# -1.89
#
#
# Realization:  14
# +0.46x_1 +1.42x_1^2x_2 +0.17x_1x_2^2
# -0.32x_1^3
#
#
# Realization:  15
# -0.92x_2^2 -1.03x_2^3
# -0.35x_2
#
#
# Realization:  16
# -0.39x_2
# -1.02x_2^3
#
#
# Realization:  17
# +1.2x_2
# -0.11x_2
#
#
# Realization:  18
# -0.22x_1^3
# +0.37x_1
#
#
# Realization:  19
# -0.94 -0.93x_1x_2^2
# -0.94x_1^2x_2

# %% [markdown]
# ### Show Max. Degree 4, degrees survive with 0.75, monomials with 0.5

# %%
process_hyperparameters = {
    "name": "Polynomials",
    "data_bulk_name": "damped_linear_theory",
    "redo": True,
    "num_realizations": global_num_realizations,
    "state_dim": global_state_dim,
    "enforce_positivity": "clip",
    "show_equation": False,
    "observed_dimension": None,
    "max_degree_drift": 4,
    "max_degree_diffusion": 0,
    "drift_params": {
        "distribution": {"name": "normal", "std": 1},
        "degree_survival_rate": 0.75,
        "monomials_survival_distribution": {"name": "fix", "fix_value": 0.5},
        "scale": {"distribution": "fix", "fix_value": 1.0},
    },
    "diffusion_params": {
        "distribution": {"name": "normal", "std": 1},
        "degree_survival_rate": 0.75,
        "monomials_survival_distribution": {"name": "fix", "fix_value": 0.5},
        "scale": {"distribution": "fix", "fix_value": 1.0},
    },
    "initial_state": normal_initial_state,
}


data, drift_params, diffusion_params = get_dynamical_system_data(
    Polynomials(process_hyperparameters), integration_config, locations_params, normalize=True, return_params=True
)
# Out:
# Finite realizations generated:   0%|                                                                                                                      | 0/20 [00:00<?, ?it/s]
# Data sample step:   0%|                                                                                                                                 | 0/1024 [00:00<?, ?it/s]
# Data sample step:   1%|█                                                                                                                        | 9/1024 [00:00<00:11, 87.45it/s]
# Data sample step:   2%|██▍                                                                                                                    | 21/1024 [00:00<00:09, 102.45it/s]
# Data sample step:   3%|███▊                                                                                                                   | 33/1024 [00:00<00:09, 108.71it/s]
# Data sample step:   4%|█████▏                                                                                                                 | 45/1024 [00:00<00:08, 111.93it/s]
# Data sample step:   6%|██████▌                                                                                                                | 57/1024 [00:00<00:08, 113.19it/s]
# Data sample step:   7%|████████                                                                                                               | 69/1024 [00:00<00:08, 111.93it/s]
# Data sample step:   8%|█████████▍                                                                                                             | 81/1024 [00:00<00:08, 109.24it/s]
# Data sample step:   9%|██████████▋                                                                                                            | 92/1024 [00:00<00:08, 103.73it/s]
# Data sample step:  10%|███████████▊                                                                                                          | 103/1024 [00:00<00:08, 103.10it/s]
# Data sample step:  11%|█████████████▏                                                                                                        | 114/1024 [00:01<00:09, 100.42it/s]
# Data sample step:  12%|██████████████▌                                                                                                        | 125/1024 [00:01<00:09, 98.83it/s]
# Data sample step:  13%|███████████████▋                                                                                                       | 135/1024 [00:01<00:09, 94.91it/s]
# Data sample step:  14%|████████████████▉                                                                                                      | 146/1024 [00:01<00:08, 97.78it/s]
# Data sample step:  15%|██████████████████                                                                                                    | 157/1024 [00:01<00:08, 100.01it/s]
# Data sample step:  17%|███████████████████▍                                                                                                  | 169/1024 [00:01<00:08, 103.89it/s]
# Data sample step:  18%|████████████████████▊                                                                                                 | 181/1024 [00:01<00:07, 107.16it/s]
████████████████████████████████████████████████████████████████████████████████████████████▉                     | 841/1024 [00:07<00:01, 114.99it/s]
# Data sample step:  83%|██████████████████████████████████████████████████████████████████████████████████████████████████▎                   | 853/1024 [00:07<00:01, 115.51it/s]
# Data sample step:  84%|███████████████████████████████████████████████████████████████████████████████████████████████████▋                  | 865/1024 [00:07<00:01, 115.21it/s]
# Data sample step:  86%|█████████████████████████████████████████████████████████████████████████████████████████████████████                 | 877/1024 [00:07<00:01, 115.74it/s]
# Data sample step:  87%|██████████████████████████████████████████████████████████████████████████████████████████████████████▍               | 889/1024 [00:07<00:01, 116.11it/s]
# Data sample step:  88%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊              | 901/1024 [00:08<00:01, 116.11it/s]
# Data sample step:  89%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▏            | 913/1024 [00:08<00:00, 114.80it/s]
# Data sample step:  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▌           | 925/1024 [00:08<00:00, 115.39it/s]
# Data sample step:  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▉          | 937/1024 [00:08<00:00, 115.78it/s]
# Data sample step:  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▎        | 949/1024 [00:08<00:00, 116.18it/s]
# Data sample step:  94%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▋       | 961/1024 [00:08<00:00, 116.19it/s]
# Data sample step:  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████      | 973/1024 [00:08<00:00, 116.66it/s]
# Data sample step:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌    | 985/1024 [00:08<00:00, 116.84it/s]
# Data sample step:  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉   | 997/1024 [00:08<00:00, 116.87it/s]
# Data sample step:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎ | 1009/1024 [00:09<00:00, 111.85it/s]
# Data sample step: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋| 1021/1024 [00:09<00:00, 111.13it/s]

# %%
Polynomials.print_polynomials(drift_params, max_degree=4, precision=2)
# Out:
# Realization:  0
# -0.71x_1 -0.9x_1^3 -2.56x_1^2x_2 -0.25x_2^3
# +0.74x_1 -0.28x_1^2 +1.78x_1x_2 +1.45x_2^2
#
#
# Realization:  1
# -0.69x_2 +1.06x_1x_2^3 +0.59x_2^4
# +1.16x_1 +1.33x_2 -0.33x_1^3 -1.25x_1^2x_2 +1.15x_1x_2^2 -1.0x_1^4
#
#
# Realization:  2
# +0.59x_1^2 -1.56x_1x_2^2 -0.04x_2^3
# +1.58x_1 -1.36x_2
#
#
# Realization:  3
# +0.99x_2 +1.64x_1x_2 +2.0x_2^2 +0.33x_1^3x_2 +0.66x_1^2x_2^2 -1.08x_1x_2^3
# -0.57 -1.39x_1 -1.26x_2 -0.5x_1^2 -0.19x_2^2 -0.19x_1x_2^2 -1.97x_2^3 -0.83x_1^3x_2 -1.3x_1^2x_2^2
#
#
# Realization:  4
# -1.0x_1x_2 -0.43x_1^4 -1.02x_1x_2^3
# +1.36x_1 -1.94x_2 -0.2x_2^3 +1.44x_1^4 +1.61x_1^3x_2 +0.45x_1^2x_2^2 +0.26x_1x_2^3
#
#
# Realization:  5
# -1.33 +0.94x_1^3x_2 +1.83x_1^2x_2^2 +0.98x_1x_2^3
# -0.7 -1.12x_2 -0.39x_1^4 -0.87x_1^2x_2^2 -0.51x_1x_2^3
#
#
# Realization:  6
# -0.05x_1x_2^2 +0.94x_2^3 +2.34x_1^3x_2 -0.15x_1^2x_2^2
# -0.67x_2 +2.05x_1x_2^2 -0.26x_2^3 -1.96x_1^4 -0.04x_1^3x_2 +0.21x_1x_2^3 +0.14x_2^4
#
#
# Realization:  7
# -0.38x_1 -1.49x_1^3 +0.16x_1^2x_2^2 +0.02x_1x_2^3 -0.8x_2^4
# -1.51x_2 +1.75x_1^4 +0.79x_1^3x_2 -1.24x_1^2x_2^2
#
#
# Realization:  8
# +0.36x_1 -0.52x_1^3 -0.65x_2^3
# -0.8x_2 -0.2x_1^2 +0.61x_2^2
#
#
# Realization:  9
# -0.33 -0.54x_1 +1.67x_2 -0.31x_1x_2^3 +1.67x_2^4
# +1.08 +2.03x_1^2 +0.61x_2^2 -0.48x_1^3 -0.75x_1^2x_2 -0.6x_1x_2^2 -0.42x_2^3
#
#
# Realization:  10
# -0.98x_2^2 +0.2x_2^3
# -1.63x_1 +0.05x_2 -0.41x_1^2 +1.16x_1x_2 -0.87x_2^2 -0.63x_1^2x_2 -0.54x_1x_2^2 -0.46x_2^3
#
#
# Realization:  11
# -1.11 +0.18x_2 -0.89x_1x_2 -1.14x_1^3 +0.65x_2^3
# -0.16x_2^3
#
#
# Realization:  12
# +0.81x_1^2 -0.92x_2^2 -0.43x_1^3 -0.42x_1x_2^2
# -0.53x_1 -0.03x_2
#
#
# Realization:  13
# -1.51x_1 -0.61x_2 -0.02x_1x_2 +0.61x_2^2 +0.13x_1^3 -1.58x_1^2x_2 -0.26x_1x_2^2 +0.31x_2^3 +1.85x_1^3x_2 +1.23x_1^2x_2^2 -0.7x_2^4
# -1.31x_1 +0.13x_1x_2^2 -0.49x_2^3 -1.45x_1^4 +0.02x_1^3x_2 +0.03x_1^2x_2^2
#
#
# Realization:  14
# -1.67 +0.14x_1 -1.39x_1x_2 -1.33x_2^2 +0.46x_1^3 -0.62x_1x_2^2 -0.28x_2^3
# +0.85x_1^3 -0.09x_1^2x_2 +0.85x_1x_2^2 -0.25x_2^3
#
#
# Realization:  15
# -0.04x_2 -0.18x_1x_2 -0.26x_1^3 -1.15x_1^2x_2 -1.62x_2^3 +0.57x_1^3x_2
# +0.58x_1 -0.06x_2 +1.14x_1^3 +0.2x_1x_2^2
#
#
# Realization:  16
# -0.1x_1 -1.24x_1^2 -0.49x_1^3 +1.05x_2^3
# +0.4x_1x_2 +0.34x_1^3 -1.76x_1x_2^2
#
#
# Realization:  17
# -1.25x_1 +1.15x_1^2 -0.03x_1x_2 -0.56x_1^3 -1.2x_2^3 -0.05x_1^4 -0.09x_1^3x_2 -0.45x_1x_2^3
# +0.25x_1^2 +0.91x_2^2 +0.4x_1^3 +1.24x_1^2x_2 +1.77x_1x_2^2 -0.96x_2^3 +0.42x_1^4 +0.84x_1x_2^3
#
#
# Realization:  18
# -0.76x_1^2 -0.2x_1x_2 +0.45x_1^3 +0.1x_1x_2^2 +1.29x_2^3 -0.6x_1x_2^3
# +1.47x_1 +0.19x_1x_2 +0.58x_2^2 -0.73x_1x_2^2 +0.8x_1^4 +0.55x_1^3x_2 -0.35x_1x_2^3
#
#
# Realization:  19
# -1.24x_1 -0.6x_1x_2 -0.61x_1x_2^2 +0.05x_1x_2^3
# -1.51 +0.16x_2^2 -0.42x_1^4
